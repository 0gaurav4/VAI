# %%
# Function to create a video with text overlay
def create_video_with_text():
    from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip

    video = VideoFileClip("car.mp4").subclip(3, 4)

    # Make the text. Many more options are available.
    txt_clip = (TextClip("Video Editing AI", fontsize=70, color='white')
                .set_position('center')
                .set_duration(10))

    result = CompositeVideoClip([video, txt_clip])  # Overlay text on video
    result.write_videofile("edited.webm", fps=25)

# %%
create_video_with_text()
# Out:
# Moviepy - Building video edited.webm.
# MoviePy - Writing audio in editedTEMP_MPY_wvf_snd.ogg
# MoviePy - Done.
# Moviepy - Writing video edited.webm
# Moviepy - Done !
# Moviepy - video ready edited.webm

# %%
# function to create clip extractor

def create_clip_extractor():
    from moviepy.editor import VideoFileClip

    video = VideoFileClip("car.mp4")
    clip = video.subclip(3, 4)
    clip.write_videofile("clip.mp4")


create_clip_extractor()
# Out:
# Moviepy - Building video clip.mp4.
# MoviePy - Writing audio in clipTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video clip.mp4
# Moviepy - Done !
# Moviepy - video ready clip.mp4

# %%
# function to create video compression

def create_video_compression():
    from moviepy.editor import VideoFileClip

    video = VideoFileClip("car.mp4")
    video = video.subclip(3, 4)
    video = video.without_audio()
    video = video.resize(0.5)
    video = video.set_fps(30)
    video.write_videofile("compressed.mp4")
    
create_video_compression()
# Out:
# Moviepy - Building video compressed.mp4.
# Moviepy - Writing video compressed.mp4
# Moviepy - Done !
# Moviepy - video ready compressed.mp4

# %%
# function to create speed adjustment of video


def create_speed_adjustment():
    from moviepy.editor import VideoFileClip, concatenate
    video = VideoFileClip("car.mp4")
    video = video.subclip(3, 4)
    video = video.speedx(0.5)
    video.write_videofile("speed.mp4")

def create_high_low_speed():
    from moviepy.editor import VideoFileClip, concatenate
    video = VideoFileClip("car.mp4")
    video_high_speed = video.subclip(3, 4).speedx(2)  # High speed segment
    video_low_speed = video.subclip(4, 5).speedx(0.5)  # Low speed segment

    final_video = concatenate([video_high_speed, video_low_speed])
    final_video.write_videofile("high_low_speed.mp4")

create_high_low_speed()
    
create_speed_adjustment()
# Out:
# Moviepy - Building video high_low_speed.mp4.
# MoviePy - Writing audio in high_low_speedTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video high_low_speed.mp4
# Moviepy - Done !
# Moviepy - video ready high_low_speed.mp4
# Moviepy - Building video speed.mp4.
# MoviePy - Writing audio in speedTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video speed.mp4
# Moviepy - Done !
# Moviepy - video ready speed.mp4

# %%
# background removal

# %%
# object detection

# %%
# background removal

def create_video_background_removal():
    import cv2
    from moviepy.editor import VideoFileClip
    video = VideoFileClip("car.mp4")
    
    def remove_background(frame):
        bgr_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        gray_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2GRAY)
        _, mask = cv2.threshold(gray_frame, 100, 255, cv2.THRESH_BINARY_INV)
        masked_frame = cv2.bitwise_and(bgr_frame, bgr_frame, mask=mask)
        return cv2.cvtColor(masked_frame, cv2.COLOR_BGR2RGB)
    
    modified_video = video.fl_image(remove_background)
    modified_video.write_videofile("remove_background.mp4", codec="libx264", audio_codec="aac", fps=video.fps)

create_video_background_removal()
# Out:
# Moviepy - Building video remove_background.mp4.
# MoviePy - Writing audio in remove_backgroundTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video remove_background.mp4
# Moviepy - Done !
# Moviepy - video ready remove_background.mp4

# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
import cv2

model = YOLO("yolov8n.pt")
names = model.names

cap = cv2.VideoCapture(r"C:\Users\gaura\Desktop\Vool2024\Vool\comvision\car.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Blur ratio
blur_ratio = 50

# Video writer
video_writer = cv2.VideoWriter("object_blurring_output.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               fps, (w, h))

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0, show=False)
    boxes = results[0].boxes.xyxy.cpu().tolist()
    clss = results[0].boxes.cls.cpu().tolist()
    annotator = Annotator(im0, line_width=2, example=names)

    if boxes is not None:
        for box, cls in zip(boxes, clss):
            annotator.box_label(box, color=colors(int(cls), True), label=names[int(cls)])

            obj = im0[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
            blur_obj = cv2.blur(obj, (blur_ratio, blur_ratio))

            im0[int(box[1]):int(box[3]), int(box[0]):int(box[2])] = blur_obj

    cv2.imshow("ultralytics", im0)
    video_writer.write(im0)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 1 airplane, 195.1ms
# Speed: 0.0ms preprocess, 195.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 130.5ms
# Speed: 3.5ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 114.5ms
# Speed: 0.0ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 101.7ms
# Speed: 4.3ms preprocess, 101.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 109.0ms
# Speed: 3.5ms preprocess, 109.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 106.6ms
# Speed: 10.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 117.2ms
# Speed: 2.3ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 113.1ms
# Speed: 0.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 101.3ms
# Speed: 2.8ms preprocess, 101.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 82.0ms
# Speed: 1.0ms preprocess, 82.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.3ms
# Speed: 0.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 0.0ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 95.0ms
# Speed: 0.6ms preprocess, 95.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 6.3ms preprocess, 98.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 101.3ms
# Speed: 0.0ms preprocess, 101.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 105.8ms
# Speed: 0.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 83.5ms
# Speed: 4.5ms preprocess, 83.5ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 100.7ms
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 96.8ms
# Speed: 3.5ms preprocess, 96.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 88.0ms
# Speed: 8.8ms preprocess, 88.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 102.1ms
# Speed: 3.5ms preprocess, 102.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 91.9ms
# Speed: 1.5ms preprocess, 91.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 95.3ms
# Speed: 0.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 97.6ms
# Speed: 0.0ms preprocess, 97.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 104.7ms
# Speed: 8.1ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 96.1ms
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 88.6ms
# Speed: 0.0ms preprocess, 88.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.1ms
# Speed: 4.3ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 140.1ms
# Speed: 0.0ms preprocess, 140.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 114.5ms
# Speed: 5.5ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 137.4ms
# Speed: 0.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 120.4ms
# Speed: 1.0ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 130.3ms
# Speed: 0.0ms preprocess, 130.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 132.8ms
# Speed: 0.0ms preprocess, 132.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 0.0ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 106.4ms
# Speed: 0.0ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.8ms
# Speed: 3.0ms preprocess, 95.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.9ms
# Speed: 0.0ms preprocess, 97.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 0.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.7ms
# Speed: 0.0ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.9ms
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 0.4ms preprocess, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 96.5ms
# Speed: 0.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.5ms
# Speed: 0.0ms preprocess, 176.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 222.8ms
# Speed: 10.2ms preprocess, 222.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.8ms
# Speed: 4.0ms preprocess, 250.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 258.8ms
# Speed: 5.5ms preprocess, 258.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 261.4ms
# Speed: 1.9ms preprocess, 261.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 253.5ms
# Speed: 2.2ms preprocess, 253.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 258.7ms
# Speed: 1.0ms preprocess, 258.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 255.0ms
# Speed: 0.0ms preprocess, 255.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 269.1ms
# Speed: 0.7ms preprocess, 269.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 253.6ms
# Speed: 2.8ms preprocess, 253.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 240.4ms
# Speed: 2.2ms preprocess, 240.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 232.5ms
# Speed: 8.4ms preprocess, 232.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.6ms
# Speed: 9.2ms preprocess, 250.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 233.1ms
# Speed: 3.3ms preprocess, 233.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.0ms
# Speed: 2.9ms preprocess, 252.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 233.5ms
# Speed: 1.9ms preprocess, 233.5ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 1 suitcase, 240.4ms
# Speed: 3.5ms preprocess, 240.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 235.8ms
# Speed: 10.8ms preprocess, 235.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 219.9ms
# Speed: 3.4ms preprocess, 219.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 230.4ms
# Speed: 1.4ms preprocess, 230.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 224.5ms
# Speed: 10.3ms preprocess, 224.5ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 219.8ms
# Speed: 0.6ms preprocess, 219.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 213.2ms
# Speed: 5.2ms preprocess, 213.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 214.4ms
# Speed: 6.2ms preprocess, 214.4ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 314.7ms
# Speed: 2.1ms preprocess, 314.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 250.7ms
# Speed: 14.8ms preprocess, 250.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 227.6ms
# Speed: 2.2ms preprocess, 227.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 248.9ms
# Speed: 2.1ms preprocess, 248.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.9ms
# Speed: 7.6ms preprocess, 214.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 235.4ms
# Speed: 2.9ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 240.2ms
# Speed: 0.0ms preprocess, 240.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 216.8ms
# Speed: 3.5ms preprocess, 216.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 220.0ms
# Speed: 2.1ms preprocess, 220.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 229.2ms
# Speed: 3.0ms preprocess, 229.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 223.3ms
# Speed: 8.1ms preprocess, 223.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 241.2ms
# Speed: 3.0ms preprocess, 241.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 222.6ms
# Speed: 2.3ms preprocess, 222.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 340.3ms
# Speed: 4.2ms preprocess, 340.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 246.1ms
# Speed: 4.8ms preprocess, 246.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 263.7ms
# Speed: 134.6ms preprocess, 263.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 231.8ms
# Speed: 6.3ms preprocess, 231.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 213.7ms
# Speed: 5.5ms preprocess, 213.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.7ms
# Speed: 3.8ms preprocess, 217.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 244.0ms
# Speed: 8.7ms preprocess, 244.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 210.7ms
# Speed: 4.9ms preprocess, 210.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 216.7ms
# Speed: 3.7ms preprocess, 216.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 247.6ms
# Speed: 5.5ms preprocess, 247.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 219.2ms
# Speed: 2.4ms preprocess, 219.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 214.3ms
# Speed: 8.0ms preprocess, 214.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 202.2ms
# Speed: 5.2ms preprocess, 202.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 236.7ms
# Speed: 14.1ms preprocess, 236.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 215.9ms
# Speed: 2.2ms preprocess, 215.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 233.2ms
# Speed: 6.8ms preprocess, 233.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 210.9ms
# Speed: 5.7ms preprocess, 210.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 234.0ms
# Speed: 4.8ms preprocess, 234.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 221.0ms
# Speed: 2.6ms preprocess, 221.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 242.2ms
# Speed: 10.9ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 234.7ms
# Speed: 3.5ms preprocess, 234.7ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 1 truck, 282.6ms
# Speed: 2.6ms preprocess, 282.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 228.2ms
# Speed: 7.5ms preprocess, 228.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 2 trucks, 220.2ms
# Speed: 2.4ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 242.5ms
# Speed: 9.9ms preprocess, 242.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 218.5ms
# Speed: 3.2ms preprocess, 218.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 225.2ms
# Speed: 2.4ms preprocess, 225.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 255.9ms
# Speed: 5.3ms preprocess, 255.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trains, 265.5ms
# Speed: 3.6ms preprocess, 265.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 traffic light, 258.4ms
# Speed: 2.0ms preprocess, 258.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 train, 247.7ms
# Speed: 4.2ms preprocess, 247.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 1 truck, 211.9ms
# Speed: 6.9ms preprocess, 211.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 217.8ms
# Speed: 3.5ms preprocess, 217.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 220.6ms
# Speed: 0.0ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 235.0ms
# Speed: 2.9ms preprocess, 235.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 237.2ms
# Speed: 0.0ms preprocess, 237.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 236.9ms
# Speed: 6.7ms preprocess, 236.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 233.4ms
# Speed: 11.2ms preprocess, 233.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 209.6ms
# Speed: 3.4ms preprocess, 209.6ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 231.8ms
# Speed: 2.9ms preprocess, 231.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 220.5ms
# Speed: 3.7ms preprocess, 220.5ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 237.1ms
# Speed: 1.0ms preprocess, 237.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 214.6ms
# Speed: 2.4ms preprocess, 214.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 234.5ms
# Speed: 3.0ms preprocess, 234.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 228.9ms
# Speed: 0.0ms preprocess, 228.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 237.1ms
# Speed: 5.6ms preprocess, 237.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 206.9ms
# Speed: 2.8ms preprocess, 206.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 226.8ms
# Speed: 6.4ms preprocess, 226.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 224.0ms
# Speed: 1.5ms preprocess, 224.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 234.1ms
# Speed: 3.5ms preprocess, 234.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 240.4ms
# Speed: 1.9ms preprocess, 240.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 220.5ms
# Speed: 1.0ms preprocess, 220.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 250.8ms
# Speed: 1.6ms preprocess, 250.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 242.4ms
# Speed: 10.2ms preprocess, 242.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.3ms
# Speed: 5.5ms preprocess, 230.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 259.5ms
# Speed: 2.2ms preprocess, 259.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 244.0ms
# Speed: 4.3ms preprocess, 244.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 236.9ms
# Speed: 3.0ms preprocess, 236.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 233.0ms
# Speed: 2.4ms preprocess, 233.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 223.7ms
# Speed: 9.8ms preprocess, 223.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.5ms
# Speed: 3.6ms preprocess, 230.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.3ms
# Speed: 4.9ms preprocess, 245.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 262.8ms
# Speed: 4.9ms preprocess, 262.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 224.5ms
# Speed: 3.4ms preprocess, 224.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 232.4ms
# Speed: 4.6ms preprocess, 232.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 235.7ms
# Speed: 0.9ms preprocess, 235.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 266.2ms
# Speed: 0.0ms preprocess, 266.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 254.1ms
# Speed: 5.1ms preprocess, 254.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 231.0ms
# Speed: 0.0ms preprocess, 231.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 206.5ms
# Speed: 6.9ms preprocess, 206.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 242.5ms
# Speed: 8.4ms preprocess, 242.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 254.0ms
# Speed: 2.2ms preprocess, 254.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 236.4ms
# Speed: 2.2ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 237.7ms
# Speed: 2.6ms preprocess, 237.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 229.2ms
# Speed: 10.5ms preprocess, 229.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 257.5ms
# Speed: 4.1ms preprocess, 257.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 259.8ms
# Speed: 4.8ms preprocess, 259.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 244.9ms
# Speed: 4.6ms preprocess, 244.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 260.7ms
# Speed: 3.7ms preprocess, 260.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 254.3ms
# Speed: 8.7ms preprocess, 254.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 1 traffic light, 221.7ms
# Speed: 7.7ms preprocess, 221.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 220.6ms
# Speed: 8.1ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.7ms
# Speed: 0.5ms preprocess, 239.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 247.7ms
# Speed: 6.5ms preprocess, 247.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 246.4ms
# Speed: 2.6ms preprocess, 246.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.3ms
# Speed: 0.9ms preprocess, 237.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.2ms
# Speed: 0.0ms preprocess, 269.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 384.3ms
# Speed: 1.5ms preprocess, 384.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 226.0ms
# Speed: 9.5ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 233.6ms
# Speed: 4.9ms preprocess, 233.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.4ms
# Speed: 3.2ms preprocess, 230.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.1ms
# Speed: 3.3ms preprocess, 242.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 220.7ms
# Speed: 1.4ms preprocess, 220.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 257.9ms
# Speed: 3.5ms preprocess, 257.9ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.2ms
# Speed: 4.4ms preprocess, 241.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 219.6ms
# Speed: 2.4ms preprocess, 219.6ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.6ms
# Speed: 0.9ms preprocess, 242.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 219.6ms
# Speed: 2.8ms preprocess, 219.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.5ms
# Speed: 5.0ms preprocess, 212.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.2ms
# Speed: 1.7ms preprocess, 245.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.4ms
# Speed: 3.4ms preprocess, 229.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 233.6ms
# Speed: 4.9ms preprocess, 233.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 226.3ms
# Speed: 3.4ms preprocess, 226.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_selfie_segmentation = mp.solutions.selfie_segmentation

# Load the video file
VIDEO_FILE = "car.mp4"

# Output video file name
OUTPUT_FILE = "outputcar.mp4"

# Background color
BG_COLOR = (192, 192, 192) # gray

# Create a video capture object
cap = cv2.VideoCapture(VIDEO_FILE)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter object
out = cv2.VideoWriter(OUTPUT_FILE, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# Initialize MediaPipe Selfie Segmentation
with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as selfie_segmentation:
    while cap.isOpened():
        # Read a frame from the video
        ret, frame = cap.read()
        if not ret:
            break
        
        # Convert the frame from BGR to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Process the frame for selfie segmentation
        results = selfie_segmentation.process(frame_rgb)
        
        # Extract the segmentation mask
        segmentation_mask = results.segmentation_mask
        
        # Create a condition for the segmentation mask
        condition = np.stack((segmentation_mask,) * 3, axis=-1) > 0.1
        
        # Create a background image
        bg_image = np.zeros(frame.shape, dtype=np.uint8)
        bg_image[:] = BG_COLOR
        
        # Replace the background with the input frame based on the segmentation mask
        output_frame = np.where(condition, frame, bg_image)
        
        # Write the output frame to the output video
        out.write(output_frame)

        # Display the output frame
        cv2.imshow('Output Video', output_frame)
        
        # Check for the 'q' key to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
